# %%
# kerastext example

# %%
import numpy as np
dat = np.load('emabse_matrices2.npz')

# %%
# load in data + embeddings
X, y, emb = dat['X'], dat['y'], dat['emb']

# %%
from kerastext import CNNTextClassifier
# Out:
# Using Theano backend.
# Using gpu device 0: GRID K520 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5005)

# %%
from hyperopt import tpe, hp, STATUS_OK, Trials
from kerastext import fmin_persist
import numpy as np


space = {
         "filter_size": hp.choice("filter_size", [[1], [2], [3], [4], [5], [6], [7], [1, 3], [1, 3, 5], [3, 5, 7]]),
         "num_filters": hp.choice('num_filters',  np.arange(50, 250, dtype=int)),
         "num_hidden_layers": hp.choice('num_hidden_layers', np.arange(0,3, dtype=int)),
         "undersample_ratio": hp.uniform('oversample_ratio', 0.2, 1),
         "dropout": hp.uniform('dropout', 0.1, 0.7),
         "class_weight": {True:hp.uniform('true_weight', 1, 30), False:1},
         "max_features": hp.choice("max_features", [5000, 10000, 12500, 15000, 17500, 20000, 25000, 30000]),
         "l2": hp.uniform('l2', 0, 3),
         "dim_hidden_layers": hp.choice("dim_hidden_layers", [50, 100, 150, 200, 250, 300, 350, 400]),
         "stopping_patience": 1,
         "stopping_target": "val_specificity_at_recall",
         "stopping_less_is_good": False,
         "validation_split":0.1
}


def objective(params):
    print(params)
    params['embedding_weights'] = emb
    clf = CNNTextClassifier(**params)
    clf.fit(X, y)
    return {'loss': -clf.history.history['val_specificity_at_recall'][-1], 'status': STATUS_OK}

# this persist version of the function helps since running 200 CNNs sequentially will
# often produce a memory error and crash... at least nothing lost
# also... it stores the evals so far to pickle, hence you can later decide to do a bunch
# more without starting from scratch
trials = fmin_persist(fn=objective,
                    space=space,
                    algo=tpe.suggest,
                    max_evals=100,
                    verbose=4,
                    trials_pickle="RCT_CNN_1.pck")

# %%
import hyperopt
optimal_params = hyperopt.space_eval(space, trials.argmin)
print(optimal_params)
# Out:
# {'l2': 0.7597291536923072, 'class_weight': {False: 1, True: 29.19848956152622}, 'stopping_less_is_good': False, 'undersample_ratio': 0.7212566713178366, 'stopping_target': 'val_specificity_at_recall', 'num_hidden_layers': 2, 'filter_size': (6,), 'stopping_patience': 1, 'validation_split': 0.1, 'dropout': 0.12879244796905195, 'num_filters': 134, 'max_features': 30000, 'dim_hidden_layers': 150}

# %%
trials = fmin_persist(fn=objective,
                    space=space,
                    algo=tpe.suggest,
                    max_evals=100,
                    verbose=4,
                    trials_pickle="RCT_CNN_1.pck")
# Out:
# {'l2': 2.113407059650438, 'class_weight': {False: 1, True: 29.83258153452071}, 'stopping_less_is_good': False, 'stopping_target': 'val_specificity_at_recall', 'num_hidden_layers': 0, 'filter_size': (3,), 'stopping_patience': 1, 'oversample_ratio': 0.9745347388823917, 'validation_split': 0.1, 'dropout': 0.37753196802434114, 'num_filters': 152, 'max_features': 15000, 'dim_hidden_layers': 200}
# Processing data (280620 samples)
# 464240 sampled indices from 252558 total, which comprise 229126.76059759464 positive, 235114 negative examples
# Sampled with ratio of 0.9745347388823917, increased to 464240 samples.
# Train on 464240 samples, validate on 28062 samples
# Epoch 1/10
# 464240/464240 [==============================] - 511s - loss: 4.5237 - acc: 0.6681 - f1_score: 0.7463 - precision: 0.6006 - recall: 0.9975 - specificity: 0.3469 - specificity_at_recall: 0.3471 - val_loss: 0.7629 - val_acc: 0.6697 - val_f1_score: 0.3224 - val_precision: 0.2125 - val_recall: 0.8798 - val_specificity: 0.6241 - val_specificity_at_recall: 0.3806
# Epoch 2/10
# 464240/464240 [==============================] - 509s - loss: 4.2913 - acc: 0.7446 - f1_score: 0.7918 - precision: 0.6597 - recall: 0.9987 - specificity: 0.4969 - specificity_at_recall: 0.4972 - val_loss: 0.4941 - val_acc: 0.8081 - val_f1_score: 0.4274 - val_precision: 0.3053 - val_recall: 0.8673 - val_specificity: 0.7828 - val_specificity_at_recall: 0.3786
# Epoch 3/10
# 464240/464240 [==============================] - 507s - loss: 4.2332 - acc: 0.7623 - f1_score: 0.8032 - precision: 0.6753 - recall: 0.9990 - specificity: 0.5315 - specificity_at_recall: 0.5319 - val_loss: 0.3668 - val_acc: 0.8748 - val_f1_score: 0.5158 - val_precision: 0.3974 - val_recall: 0.8526 - val_specificity: 0.8599 - val_specificity_at_recall: 0.3769
# Trial 42 done!.. pickling...
# {'l2': 2.321343135890656, 'class_weight': {False: 1, True: 28.115631605208314}, 'stopping_less_is_good': False, 'stopping_target': 'val_specificity_at_recall', 'num_hidden_layers': 0, 'filter_size': (3,), 'stopping_patience': 1, 'oversample_ratio': 0.9333902885880284, 'validation_split': 0.1, 'dropout': 0.552474863367241, 'num_filters': 236, 'max_features': 15000, 'dim_hidden_layers': 200}
# Processing data (280620 samples)
# 454567 sampled indices from 252558 total, which comprise 219453.1243110857 positive, 235114 negative examples
# Sampled with ratio of 0.9333902885880284, increased to 454567 samples.
# Train on 454567 samples, validate on 28062 samples
# Epoch 1/10
# 454567/454567 [==============================] - 626s - loss: 5.6653 - acc: 0.6590 - f1_score: 0.7358 - precision: 0.5863 - recall: 0.9986 - specificity: 0.3420 - specificity_at_recall: 0.3420 - val_loss: 0.4957 - val_acc: 0.7903 - val_f1_score: 0.4117 - val_precision: 0.2907 - val_recall: 0.8688 - val_specificity: 0.7620 - val_specificity_at_recall: 0.3767
# Trial 43 done!.. pickling...
# {'l2': 2.532037796919997, 'class_weight': {False: 1, True: 26.08585020732051}, 'stopping_less_is_good': False, 'stopping_target': 'val_specificity_at_recall', 'num_hidden_layers': 2, 'filter_size': (3,), 'stopping_patience': 1, 'oversample_ratio': 0.8937242766736841, 'validation_split': 0.1, 'dropout': 0.4014642854849293, 'num_filters': 239, 'max_features': 15000, 'dim_hidden_layers': 200}
# Processing data (280620 samples)
# 445241 sampled indices from 252558 total, which comprise 210127.08958585656 positive, 235114 negative examples
# Sampled with ratio of 0.8937242766736841, increased to 445241 samples.
# Train on 445241 samples, validate on 28062 samples
# Epoch 1/10
# 445241/445241 [==============================] - 627s - loss: 9.3176 - acc: 0.5272 - f1_score: 0.6649 - precision: 0.5032 - recall: 0.9987 - specificity: 0.1062 - specificity_at_recall: 0.1062 - val_loss: 0.9656 - val_acc: 0.5856 - val_f1_score: 0.2852 - val_precision: 0.1832 - val_recall: 0.8877 - val_specificity: 0.5303 - val_specificity_at_recall: 0.3734
# Epoch 2/10
# 445241/445241 [==============================] - 621s - loss: 4.2018 - acc: 0.6874 - f1_score: 0.7478 - precision: 0.6026 - recall: 0.9964 - specificity: 0.4113 - specificity_at_recall: 0.4113 - val_loss: 0.7591 - val_acc: 0.7395 - val_f1_score: 0.3680 - val_precision: 0.2509 - val_recall: 0.8768 - val_specificity: 0.7046 - val_specificity_at_recall: 0.3692
# Epoch 3/10
# 357300/402873 [=========================>....] - ETA: 57s - loss: 3.9858 - acc: 0.6269 - f1_score: 0.6867 - precision: 0.5279 - recall: 0.9972 - specificity: 0.3628 - specificity_at_recall: 0.3627

# %%
# demo of loading the trials data
import pickle
with open("RCT_CNN_1.pck", 'rb') as f:
    t = pickle.load(f)

# %%
len(t) # number of trials so far
# Out:
# 41

# %%
t.trials # the params
# Out:
# [{'book_time': datetime.datetime(2016, 10, 4, 15, 58, 27, 176000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [0],
#     'dropout': [0],
#     'filter_size': [0],
#     'l2': [0],
#     'max_features': [0],
#     'num_filters': [0],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0],
#     'true_weight': [0]},
#    'tid': 0,
#    'vals': {'dim_hidden_layers': [3],
#     'dropout': [0.37520755829191943],
#     'filter_size': [1],
#     'l2': [2.0924613767363596],
#     'max_features': [5],
#     'num_filters': [152],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.8130407613298556],
#     'true_weight': [23.34346564022296]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 16, 1, 11, 723000),
#   'result': {'loss': -0.11537114970251153, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 0,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 16, 2, 40, 933000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [1],
#     'dropout': [1],
#     'filter_size': [1],
#     'l2': [1],
#     'max_features': [1],
#     'num_filters': [1],
#     'num_hidden_layers': [1],
#     'oversample_ratio': [1],
#     'true_weight': [1]},
#    'tid': 1,
#    'vals': {'dim_hidden_layers': [2],
#     'dropout': [0.12879244796905195],
#     'filter_size': [5],
#     'l2': [0.7597291536923072],
#     'max_features': [7],
#     'num_filters': [84],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.7212566713178366],
#     'true_weight': [29.19848956152622]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 16, 9, 19, 487000),
#   'result': {'loss': -0.36697310144172646, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 1,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 16, 12, 48, 100000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [2],
#     'dropout': [2],
#     'filter_size': [2],
#     'l2': [2],
#     'max_features': [2],
#     'num_filters': [2],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [2],
#     'true_weight': [2]},
#    'tid': 2,
#    'vals': {'dim_hidden_layers': [0],
#     'dropout': [0.13083210282621635],
#     'filter_size': [5],
#     'l2': [2.621829311844896],
#     'max_features': [3],
#     'num_filters': [8],
#     'num_hidden_layers': [1],
#     'oversample_ratio': [0.5968542620331287],
#     'true_weight': [11.935406846265918]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 16, 27, 21, 841000),
#   'result': {'loss': -0.3611471210657174, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 2,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 16, 27, 21, 873000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [3],
#     'dropout': [3],
#     'filter_size': [3],
#     'l2': [3],
#     'max_features': [3],
#     'num_filters': [3],
#     'num_hidden_layers': [3],
#     'oversample_ratio': [3],
#     'true_weight': [3]},
#    'tid': 3,
#    'vals': {'dim_hidden_layers': [0],
#     'dropout': [0.2678263309285783],
#     'filter_size': [7],
#     'l2': [1.645928336431188],
#     'max_features': [3],
#     'num_filters': [0],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.3472478060863575],
#     'true_weight': [29.34925710971223]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 16, 44, 27, 914000),
#   'result': {'loss': -0.36155431172341546, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 3,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 16, 44, 27, 947000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [4],
#     'dropout': [4],
#     'filter_size': [4],
#     'l2': [4],
#     'max_features': [4],
#     'num_filters': [4],
#     'num_hidden_layers': [4],
#     'oversample_ratio': [4],
#     'true_weight': [4]},
#    'tid': 4,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.2886648891879884],
#     'filter_size': [9],
#     'l2': [2.728652627503465],
#     'max_features': [1],
#     'num_filters': [41],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.777256464130768],
#     'true_weight': [27.776253969574253]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 17, 35, 40, 21000),
#   'result': {'loss': -0.37860444216367634, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 4,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 17, 35, 40, 54000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [5],
#     'dropout': [5],
#     'filter_size': [5],
#     'l2': [5],
#     'max_features': [5],
#     'num_filters': [5],
#     'num_hidden_layers': [5],
#     'oversample_ratio': [5],
#     'true_weight': [5]},
#    'tid': 5,
#    'vals': {'dim_hidden_layers': [7],
#     'dropout': [0.5112708360582278],
#     'filter_size': [4],
#     'l2': [0.6895299756866192],
#     'max_features': [2],
#     'num_filters': [199],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.9502003057583768],
#     'true_weight': [9.458187826167306]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 18, 27, 51, 161000),
#   'result': {'loss': -0.359814779838402, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 5,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 18, 27, 51, 193000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [6],
#     'dropout': [6],
#     'filter_size': [6],
#     'l2': [6],
#     'max_features': [6],
#     'num_filters': [6],
#     'num_hidden_layers': [6],
#     'oversample_ratio': [6],
#     'true_weight': [6]},
#    'tid': 6,
#    'vals': {'dim_hidden_layers': [0],
#     'dropout': [0.5615659036725228],
#     'filter_size': [0],
#     'l2': [2.7144902458508917],
#     'max_features': [5],
#     'num_filters': [116],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.28519681834806543],
#     'true_weight': [6.200941025485255]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 18, 41, 17, 342000),
#   'result': {'loss': -0.0, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 6,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 18, 41, 17, 375000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [7],
#     'dropout': [7],
#     'filter_size': [7],
#     'l2': [7],
#     'max_features': [7],
#     'num_filters': [7],
#     'num_hidden_layers': [7],
#     'oversample_ratio': [7],
#     'true_weight': [7]},
#    'tid': 7,
#    'vals': {'dim_hidden_layers': [7],
#     'dropout': [0.6444791532645023],
#     'filter_size': [6],
#     'l2': [2.142201426578372],
#     'max_features': [6],
#     'num_filters': [49],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.8835003883544525],
#     'true_weight': [10.805647269716435]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 19, 21, 45, 895000),
#   'result': {'loss': -0.3480342165613776, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 7,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 19, 52, 32, 117000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [8],
#     'dropout': [8],
#     'filter_size': [8],
#     'l2': [8],
#     'max_features': [8],
#     'num_filters': [8],
#     'num_hidden_layers': [8],
#     'oversample_ratio': [8],
#     'true_weight': [8]},
#    'tid': 8,
#    'vals': {'dim_hidden_layers': [3],
#     'dropout': [0.4525618254547362],
#     'filter_size': [9],
#     'l2': [1.9805310801665355],
#     'max_features': [0],
#     'num_filters': [179],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.664916659260633],
#     'true_weight': [23.60598770442275]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 21, 23, 56, 483000),
#   'result': {'loss': -0.0, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 8,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 21, 23, 56, 516000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [9],
#     'dropout': [9],
#     'filter_size': [9],
#     'l2': [9],
#     'max_features': [9],
#     'num_filters': [9],
#     'num_hidden_layers': [9],
#     'oversample_ratio': [9],
#     'true_weight': [9]},
#    'tid': 9,
#    'vals': {'dim_hidden_layers': [3],
#     'dropout': [0.3971656569065022],
#     'filter_size': [7],
#     'l2': [2.0602357431527296],
#     'max_features': [6],
#     'num_filters': [164],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.4319002995497001],
#     'true_weight': [21.492135577328927]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 22, 14, 47, 124000),
#   'result': {'loss': -0.37230879730011257, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 9,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 22, 14, 47, 158000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [10],
#     'dropout': [10],
#     'filter_size': [10],
#     'l2': [10],
#     'max_features': [10],
#     'num_filters': [10],
#     'num_hidden_layers': [10],
#     'oversample_ratio': [10],
#     'true_weight': [10]},
#    'tid': 10,
#    'vals': {'dim_hidden_layers': [4],
#     'dropout': [0.30121469871857376],
#     'filter_size': [0],
#     'l2': [0.19580023428621718],
#     'max_features': [1],
#     'num_filters': [161],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.9176846385645161],
#     'true_weight': [7.870408079829458]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 22, 44, 30, 264000),
#   'result': {'loss': -0.35577943111407373, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 10,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 22, 44, 30, 297000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [11],
#     'dropout': [11],
#     'filter_size': [11],
#     'l2': [11],
#     'max_features': [11],
#     'num_filters': [11],
#     'num_hidden_layers': [11],
#     'oversample_ratio': [11],
#     'true_weight': [11]},
#    'tid': 11,
#    'vals': {'dim_hidden_layers': [5],
#     'dropout': [0.1881289383621913],
#     'filter_size': [3],
#     'l2': [2.266499454326621],
#     'max_features': [6],
#     'num_filters': [132],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.31354118583943374],
#     'true_weight': [10.37856486550673]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 23, 5, 4, 370000),
#   'result': {'loss': -0.36820710880474644, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 11,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 23, 5, 4, 403000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [12],
#     'dropout': [12],
#     'filter_size': [12],
#     'l2': [12],
#     'max_features': [12],
#     'num_filters': [12],
#     'num_hidden_layers': [12],
#     'oversample_ratio': [12],
#     'true_weight': [12]},
#    'tid': 12,
#    'vals': {'dim_hidden_layers': [7],
#     'dropout': [0.5128227621588478],
#     'filter_size': [4],
#     'l2': [0.3131079903256596],
#     'max_features': [4],
#     'num_filters': [7],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.46578375779790965],
#     'true_weight': [17.41291443719739]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 23, 17, 59, 880000),
#   'result': {'loss': -0.37234498326094556, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 12,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 23, 17, 59, 913000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [13],
#     'dropout': [13],
#     'filter_size': [13],
#     'l2': [13],
#     'max_features': [13],
#     'num_filters': [13],
#     'num_hidden_layers': [13],
#     'oversample_ratio': [13],
#     'true_weight': [13]},
#    'tid': 13,
#    'vals': {'dim_hidden_layers': [7],
#     'dropout': [0.4464219507438263],
#     'filter_size': [4],
#     'l2': [1.7675430565074075],
#     'max_features': [0],
#     'num_filters': [81],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.7393017581885613],
#     'true_weight': [7.269915955017126]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 4, 23, 52, 39, 565000),
#   'result': {'loss': -0.3744488984386746, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 13,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 4, 23, 52, 39, 598000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [14],
#     'dropout': [14],
#     'filter_size': [14],
#     'l2': [14],
#     'max_features': [14],
#     'num_filters': [14],
#     'num_hidden_layers': [14],
#     'oversample_ratio': [14],
#     'true_weight': [14]},
#    'tid': 14,
#    'vals': {'dim_hidden_layers': [7],
#     'dropout': [0.2324387691759509],
#     'filter_size': [8],
#     'l2': [1.9184091796485676],
#     'max_features': [6],
#     'num_filters': [156],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.47297574647738144],
#     'true_weight': [1.0952203998054157]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 1, 36, 9, 609000),
#   'result': {'loss': -0.35582684746710236, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 14,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 1, 36, 9, 643000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [15],
#     'dropout': [15],
#     'filter_size': [15],
#     'l2': [15],
#     'max_features': [15],
#     'num_filters': [15],
#     'num_hidden_layers': [15],
#     'oversample_ratio': [15],
#     'true_weight': [15]},
#    'tid': 15,
#    'vals': {'dim_hidden_layers': [4],
#     'dropout': [0.30749049520716115],
#     'filter_size': [7],
#     'l2': [0.0848978570333988],
#     'max_features': [7],
#     'num_filters': [123],
#     'num_hidden_layers': [1],
#     'oversample_ratio': [0.46695931870561325],
#     'true_weight': [10.726229769161618]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 2, 11, 1, 39000),
#   'result': {'loss': -0.3620584660741587, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 15,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 2, 11, 1, 75000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [16],
#     'dropout': [16],
#     'filter_size': [16],
#     'l2': [16],
#     'max_features': [16],
#     'num_filters': [16],
#     'num_hidden_layers': [16],
#     'oversample_ratio': [16],
#     'true_weight': [16]},
#    'tid': 16,
#    'vals': {'dim_hidden_layers': [7],
#     'dropout': [0.21919466533157153],
#     'filter_size': [0],
#     'l2': [0.2653620303281071],
#     'max_features': [3],
#     'num_filters': [81],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.6888140266924323],
#     'true_weight': [17.24321864091637]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 2, 26, 40, 243000),
#   'result': {'loss': -0.3676483854327536, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 16,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 2, 26, 40, 278000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [17],
#     'dropout': [17],
#     'filter_size': [17],
#     'l2': [17],
#     'max_features': [17],
#     'num_filters': [17],
#     'num_hidden_layers': [17],
#     'oversample_ratio': [17],
#     'true_weight': [17]},
#    'tid': 17,
#    'vals': {'dim_hidden_layers': [5],
#     'dropout': [0.17331369770898492],
#     'filter_size': [9],
#     'l2': [0.21553626040034457],
#     'max_features': [5],
#     'num_filters': [124],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.4335221007594447],
#     'true_weight': [26.856013099540142]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 3, 57, 33, 978000),
#   'result': {'loss': -0.3736200545352996, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 17,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 3, 57, 34, 11000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [18],
#     'dropout': [18],
#     'filter_size': [18],
#     'l2': [18],
#     'max_features': [18],
#     'num_filters': [18],
#     'num_hidden_layers': [18],
#     'oversample_ratio': [18],
#     'true_weight': [18]},
#    'tid': 18,
#    'vals': {'dim_hidden_layers': [2],
#     'dropout': [0.44905769442187116],
#     'filter_size': [6],
#     'l2': [0.79976110198562],
#     'max_features': [4],
#     'num_filters': [173],
#     'num_hidden_layers': [2],
#     'oversample_ratio': [0.467775657304128],
#     'true_weight': [28.50230759432258]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 4, 29, 59, 716000),
#   'result': {'loss': -0.3732472594436326, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 18,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 4, 29, 59, 750000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [19],
#     'dropout': [19],
#     'filter_size': [19],
#     'l2': [19],
#     'max_features': [19],
#     'num_filters': [19],
#     'num_hidden_layers': [19],
#     'oversample_ratio': [19],
#     'true_weight': [19]},
#    'tid': 19,
#    'vals': {'dim_hidden_layers': [3],
#     'dropout': [0.45313079357252606],
#     'filter_size': [3],
#     'l2': [2.2345406670653336],
#     'max_features': [2],
#     'num_filters': [92],
#     'num_hidden_layers': [1],
#     'oversample_ratio': [0.33539898097558607],
#     'true_weight': [24.59619474519141]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 4, 54, 4, 112000),
#   'result': {'loss': -0.37318363503778185, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 19,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 4, 54, 4, 155000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [20],
#     'dropout': [20],
#     'filter_size': [20],
#     'l2': [20],
#     'max_features': [20],
#     'num_filters': [20],
#     'num_hidden_layers': [20],
#     'oversample_ratio': [20],
#     'true_weight': [20]},
#    'tid': 20,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.34345187381850506],
#     'filter_size': [2],
#     'l2': [1.3727941738420268],
#     'max_features': [1],
#     'num_filters': [144],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.8020968748622249],
#     'true_weight': [2.2418280960809005]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 5, 19, 35, 771000),
#   'result': {'loss': -0.3714197634478168, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 20,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 5, 19, 35, 814000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [21],
#     'dropout': [21],
#     'filter_size': [21],
#     'l2': [21],
#     'max_features': [21],
#     'num_filters': [21],
#     'num_hidden_layers': [21],
#     'oversample_ratio': [21],
#     'true_weight': [21]},
#    'tid': 21,
#    'vals': {'dim_hidden_layers': [6],
#     'dropout': [0.6239935157437397],
#     'filter_size': [4],
#     'l2': [2.9390108019047623],
#     'max_features': [0],
#     'num_filters': [127],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.7917681444022195],
#     'true_weight': [4.637443426237809]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 5, 48, 55, 161000),
#   'result': {'loss': -0.3668771111636379, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 21,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 6, 44, 26, 974000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [22],
#     'dropout': [22],
#     'filter_size': [22],
#     'l2': [22],
#     'max_features': [22],
#     'num_filters': [22],
#     'num_hidden_layers': [22],
#     'oversample_ratio': [22],
#     'true_weight': [22]},
#    'tid': 22,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.34877898240972965],
#     'filter_size': [9],
#     'l2': [1.2624533714214539],
#     'max_features': [0],
#     'num_filters': [41],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.5683266282123267],
#     'true_weight': [14.680574415556674]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 7, 29, 29, 954000),
#   'result': {'loss': -0.3735899555384497, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 22,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 7, 29, 29, 996000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [23],
#     'dropout': [23],
#     'filter_size': [23],
#     'l2': [23],
#     'max_features': [23],
#     'num_filters': [23],
#     'num_hidden_layers': [23],
#     'oversample_ratio': [23],
#     'true_weight': [23]},
#    'tid': 23,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.5693324638284318],
#     'filter_size': [9],
#     'l2': [2.5884751552343697],
#     'max_features': [1],
#     'num_filters': [25],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.9813724729744799],
#     'true_weight': [14.500884864793047]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 8, 22, 48, 675000),
#   'result': {'loss': -0.37395253285790075, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 23,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 8, 22, 48, 718000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [24],
#     'dropout': [24],
#     'filter_size': [24],
#     'l2': [24],
#     'max_features': [24],
#     'num_filters': [24],
#     'num_hidden_layers': [24],
#     'oversample_ratio': [24],
#     'true_weight': [24]},
#    'tid': 24,
#    'vals': {'dim_hidden_layers': [6],
#     'dropout': [0.6996691236798585],
#     'filter_size': [4],
#     'l2': [1.6607927728208747],
#     'max_features': [1],
#     'num_filters': [119],
#     'num_hidden_layers': [1],
#     'oversample_ratio': [0.8506207204994463],
#     'true_weight': [20.048078101977843]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 8, 52, 51, 255000),
#   'result': {'loss': -0.36692646627525, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 24,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 8, 52, 51, 298000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [25],
#     'dropout': [25],
#     'filter_size': [25],
#     'l2': [25],
#     'max_features': [25],
#     'num_filters': [25],
#     'num_hidden_layers': [25],
#     'oversample_ratio': [25],
#     'true_weight': [25]},
#    'tid': 25,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.2825042537210826],
#     'filter_size': [1],
#     'l2': [2.979164777949193],
#     'max_features': [0],
#     'num_filters': [197],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.7558163279348283],
#     'true_weight': [6.921243122024592]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 9, 18, 8, 392000),
#   'result': {'loss': -0.37769490729359767, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 25,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 9, 18, 8, 436000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [26],
#     'dropout': [26],
#     'filter_size': [26],
#     'l2': [26],
#     'max_features': [26],
#     'num_filters': [26],
#     'num_hidden_layers': [26],
#     'oversample_ratio': [26],
#     'true_weight': [26]},
#    'tid': 26,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.2645929110433998],
#     'filter_size': [1],
#     'l2': [2.959769187514525],
#     'max_features': [0],
#     'num_filters': [82],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.661804551412435],
#     'true_weight': [3.7163443843689086]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 9, 35, 14, 471000),
#   'result': {'loss': -0.37500394810784715, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 26,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 9, 35, 14, 514000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [27],
#     'dropout': [27],
#     'filter_size': [27],
#     'l2': [27],
#     'max_features': [27],
#     'num_filters': [27],
#     'num_hidden_layers': [27],
#     'oversample_ratio': [27],
#     'true_weight': [27]},
#    'tid': 27,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.16908532802975984],
#     'filter_size': [1],
#     'l2': [2.792561973190179],
#     'max_features': [1],
#     'num_filters': [197],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.567672657478481],
#     'true_weight': [12.5784805027359]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 9, 58, 6, 326000),
#   'result': {'loss': -0.37311706634896946, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 27,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 9, 58, 6, 370000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [28],
#     'dropout': [28],
#     'filter_size': [28],
#     'l2': [28],
#     'max_features': [28],
#     'num_filters': [28],
#     'num_hidden_layers': [28],
#     'oversample_ratio': [28],
#     'true_weight': [28]},
#    'tid': 28,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.35777638671014167],
#     'filter_size': [1],
#     'l2': [2.391150904390625],
#     'max_features': [4],
#     'num_filters': [13],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.7655584946886654],
#     'true_weight': [18.525050482215732]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 10, 10, 17, 475000),
#   'result': {'loss': -0.37760662755132884, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 28,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 10, 10, 17, 520000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [29],
#     'dropout': [29],
#     'filter_size': [29],
#     'l2': [29],
#     'max_features': [29],
#     'num_filters': [29],
#     'num_hidden_layers': [29],
#     'oversample_ratio': [29],
#     'true_weight': [29]},
#    'tid': 29,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.10976974932862874],
#     'filter_size': [2],
#     'l2': [2.5026483507691872],
#     'max_features': [1],
#     'num_filters': [122],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.8381127994900798],
#     'true_weight': [25.186382145774953]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 10, 34, 53, 322000),
#   'result': {'loss': -0.3721277087774996, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 29,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 10, 34, 53, 366000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [30],
#     'dropout': [30],
#     'filter_size': [30],
#     'l2': [30],
#     'max_features': [30],
#     'num_filters': [30],
#     'num_hidden_layers': [30],
#     'oversample_ratio': [30],
#     'true_weight': [30]},
#    'tid': 30,
#    'vals': {'dim_hidden_layers': [2],
#     'dropout': [0.3093726692593833],
#     'filter_size': [8],
#     'l2': [2.945171176353587],
#     'max_features': [7],
#     'num_filters': [17],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.9967604506918393],
#     'true_weight': [21.506114359656475]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 11, 33, 2, 355000),
#   'result': {'loss': -0.3727439583505734, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 30,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 11, 33, 2, 399000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [31],
#     'dropout': [31],
#     'filter_size': [31],
#     'l2': [31],
#     'max_features': [31],
#     'num_filters': [31],
#     'num_hidden_layers': [31],
#     'oversample_ratio': [31],
#     'true_weight': [31]},
#    'tid': 31,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.39169054526306035],
#     'filter_size': [1],
#     'l2': [1.0687735475691826],
#     'max_features': [0],
#     'num_filters': [61],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.2198142449122179],
#     'true_weight': [13.229513940175849]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 11, 46, 45, 96000),
#   'result': {'loss': -0.37449061076451706, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 31,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 11, 46, 45, 141000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [32],
#     'dropout': [32],
#     'filter_size': [32],
#     'l2': [32],
#     'max_features': [32],
#     'num_filters': [32],
#     'num_hidden_layers': [32],
#     'oversample_ratio': [32],
#     'true_weight': [32]},
#    'tid': 32,
#    'vals': {'dim_hidden_layers': [5],
#     'dropout': [0.2589369780884311],
#     'filter_size': [5],
#     'l2': [2.7712957470304938],
#     'max_features': [2],
#     'num_filters': [192],
#     'num_hidden_layers': [1],
#     'oversample_ratio': [0.6257474419539627],
#     'true_weight': [4.869945695385349]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 12, 20, 59, 365000),
#   'result': {'loss': -0.36507180585472765, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 32,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 12, 20, 59, 409000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [33],
#     'dropout': [33],
#     'filter_size': [33],
#     'l2': [33],
#     'max_features': [33],
#     'num_filters': [33],
#     'num_hidden_layers': [33],
#     'oversample_ratio': [33],
#     'true_weight': [33]},
#    'tid': 33,
#    'vals': {'dim_hidden_layers': [6],
#     'dropout': [0.13900470903283105],
#     'filter_size': [9],
#     'l2': [2.398111621960914],
#     'max_features': [3],
#     'num_filters': [75],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.7178404095994755],
#     'true_weight': [8.860384542576092]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 13, 17, 34, 339000),
#   'result': {'loss': -0.37196150641508974, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 33,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 13, 17, 34, 384000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [34],
#     'dropout': [34],
#     'filter_size': [34],
#     'l2': [34],
#     'max_features': [34],
#     'num_filters': [34],
#     'num_hidden_layers': [34],
#     'oversample_ratio': [34],
#     'true_weight': [34]},
#    'tid': 34,
#    'vals': {'dim_hidden_layers': [0],
#     'dropout': [0.2089667549951326],
#     'filter_size': [1],
#     'l2': [1.841450730786044],
#     'max_features': [5],
#     'num_filters': [48],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.5273337437564257],
#     'true_weight': [27.27946151979856]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 13, 30, 22, 341000),
#   'result': {'loss': -0.3739820006714689, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 34,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 13, 30, 22, 388000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [35],
#     'dropout': [35],
#     'filter_size': [35],
#     'l2': [35],
#     'max_features': [35],
#     'num_filters': [35],
#     'num_hidden_layers': [35],
#     'oversample_ratio': [35],
#     'true_weight': [35]},
#    'tid': 35,
#    'vals': {'dim_hidden_layers': [4],
#     'dropout': [0.2897070838329547],
#     'filter_size': [5],
#     'l2': [1.5067262218430382],
#     'max_features': [7],
#     'num_filters': [162],
#     'num_hidden_layers': [1],
#     'oversample_ratio': [0.8864030692817015],
#     'true_weight': [2.347389362626135]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 14, 8, 2, 639000),
#   'result': {'loss': -0.3556496441347296, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 35,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 14, 8, 2, 686000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [36],
#     'dropout': [36],
#     'filter_size': [36],
#     'l2': [36],
#     'max_features': [36],
#     'num_filters': [36],
#     'num_hidden_layers': [36],
#     'oversample_ratio': [36],
#     'true_weight': [36]},
#    'tid': 36,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.24347445762159522],
#     'filter_size': [9],
#     'l2': [2.675868849057239],
#     'max_features': [0],
#     'num_filters': [160],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.923997042725735],
#     'true_weight': [6.134293994898383]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 15, 48, 10, 190000),
#   'result': {'loss': -0.3771019983760825, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 36,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 15, 48, 10, 239000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [37],
#     'dropout': [37],
#     'filter_size': [37],
#     'l2': [37],
#     'max_features': [37],
#     'num_filters': [37],
#     'num_hidden_layers': [37],
#     'oversample_ratio': [37],
#     'true_weight': [37]},
#    'tid': 37,
#    'vals': {'dim_hidden_layers': [2],
#     'dropout': [0.41679664156286655],
#     'filter_size': [6],
#     'l2': [2.9928183152915233],
#     'max_features': [2],
#     'num_filters': [151],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.7642012956049696],
#     'true_weight': [15.773671235904803]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 16, 25, 11, 653000),
#   'result': {'loss': -0.37535944716664654, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 37,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 16, 25, 11, 701000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [38],
#     'dropout': [38],
#     'filter_size': [38],
#     'l2': [38],
#     'max_features': [38],
#     'num_filters': [38],
#     'num_hidden_layers': [38],
#     'oversample_ratio': [38],
#     'true_weight': [38]},
#    'tid': 38,
#    'vals': {'dim_hidden_layers': [0],
#     'dropout': [0.4992144985197472],
#     'filter_size': [8],
#     'l2': [2.839158558219641],
#     'max_features': [1],
#     'num_filters': [177],
#     'num_hidden_layers': [1],
#     'oversample_ratio': [0.6170562715988089],
#     'true_weight': [21.671011496578664]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 17, 36, 26, 772000),
#   'result': {'loss': -0.367230171429721, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 38,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 17, 36, 26, 820000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [39],
#     'dropout': [39],
#     'filter_size': [39],
#     'l2': [39],
#     'max_features': [39],
#     'num_filters': [39],
#     'num_hidden_layers': [39],
#     'oversample_ratio': [39],
#     'true_weight': [39]},
#    'tid': 39,
#    'vals': {'dim_hidden_layers': [1],
#     'dropout': [0.3301118304130709],
#     'filter_size': [3],
#     'l2': [0.5975655672040601],
#     'max_features': [5],
#     'num_filters': [40],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.8405212587584872],
#     'true_weight': [11.786409137102332]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 18, 0, 20, 392000),
#   'result': {'loss': -0.37211010992042726, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 39,
#   'version': 0},
#  {'book_time': datetime.datetime(2016, 10, 5, 18, 0, 20, 440000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dim_hidden_layers': [40],
#     'dropout': [40],
#     'filter_size': [40],
#     'l2': [40],
#     'max_features': [40],
#     'num_filters': [40],
#     'num_hidden_layers': [40],
#     'oversample_ratio': [40],
#     'true_weight': [40]},
#    'tid': 40,
#    'vals': {'dim_hidden_layers': [3],
#     'dropout': [0.3725398956526291],
#     'filter_size': [2],
#     'l2': [2.1063133407137915],
#     'max_features': [3],
#     'num_filters': [186],
#     'num_hidden_layers': [0],
#     'oversample_ratio': [0.9581583842368202],
#     'true_weight': [29.68366103248428]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2016, 10, 5, 18, 32, 14, 848000),
#   'result': {'loss': -0.3792473776331691, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 40,
#   'version': 0}]
